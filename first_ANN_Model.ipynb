# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashGit95/First_ANN_Model/blob/main/first_ANN_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import data

# %%
import pandas as pd
file_path = '/content/Mobile_Price_Classification-220531-204702.csv'
df= pd.read_csv(file_path)
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# Separate independent and depndent variables

# %%
x = df.drop(['price_range'], axis=1)
y = df['price_range']
print(y)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1995    0
# 1996    0
# 1997    1
# 1998    0
# 1999    1
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.25)

# %% [markdown]
# Import dependencies

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout

# %% [markdown]
# Build the model

# %%
model=Sequential()
model.add(Dense(units=8,activation='relu', input_dim = len(X_train.columns)))
model.add(Dense(units=4,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 168
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dense_2 (Dense)             (None, 1)                 5
#
# ...
# Total params: 209 (836.00 Byte)
# Trainable params: 209 (836.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer ='sgd', metrics='accuracy')

# %%
model.fit(X_train,Y_train, validation_data=(X_test,Y_test), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 6s 12ms/step - loss: 4.9037 - accuracy: 0.4933 - val_loss: 0.6931 - val_accuracy: 0.5160
# Epoch 2/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.4853 - val_loss: 0.6932 - val_accuracy: 0.4840
# Epoch 3/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.4947 - val_loss: 0.6932 - val_accuracy: 0.4840
# Epoch 4/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5053 - val_loss: 0.6932 - val_accuracy: 0.4840
# Epoch 5/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5053 - val_loss: 0.6933 - val_accuracy: 0.4840
# Epoch 6/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5053 - val_loss: 0.6933 - val_accuracy: 0.4840
# Epoch 7/100
# ...

# %%
model.save('weights.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
